# %% [markdown]
# # Lists — Practice Questions
# ### Hospital Data Context
# ---

# %% [markdown]
# ## Section 1 — Indexing

# %%
doctors = ["Dr. Sharma", "Dr. Patel", "Dr. Rao", "Dr. Nair", "Dr. Mehta"]

# %%
# 1. Print the third doctor using positive index
print(doctors[2])
# Out:
# Dr. Rao

# %%
# 2. Print the third doctor using negative index
print(doctors[-3])
# Out:
# Dr. Rao

# %%
# 3. Print the first and last doctor in a single print statement
print(doctors[0], doctors[4])
# Out:
# Dr. Sharma Dr. Mehta

# %%
# 4. A new doctor "Dr. Khan" was added — what index will she be at?
#    Add her and verify using indexing
doctors.append("Dr. Khan")
print(doctors[5])
# Out:
# Dr. Khan

# %%
# 5. Print the middle doctor from the updated list
print(doctors[2])
# Out:
# Dr. Rao

# %% [markdown]
# ---
# ## Section 2 — Slicing

# %%
patient_count = [120, 135, 98, 160, 145, 110, 130, 155, 140, 125, 150, 170]
#                J    F    M   A    M    J    J    A    S    O    N    D

# %%
# 1. Get Q2 and Q3 together in one slice (Apr to Sep)

# %%
# 2. Get every 3rd month starting from January

# %%
# 3. Get the last 6 months in reverse order

# %%
# 4. Get months from March to October using index numbers

# %%
# 5. Slice out only the months where position is even (index 0,2,4...)

# %%
# 6. Get Q4 and reverse it — which month had highest patients?

# %% [markdown]
# ---
# ## Section 3 — Mutability

# %%
patient = ["Rahul Verma", "General Ward", 1200, ["Paracetamol", "Ibuprofen"]]
#           name            ward          charge   medications

# %%
# 1. Rahul was moved — change ward to "ICU"

# %%
# 2. Update daily charge to 4500

# %%
# 3. Add "Metformin" to his medications list

# %%
# 4. Make a copy called old_record

# %%
# 5. Change the ward in old_record back to "General Ward"

# %%
# 6. Print both — patient should still show "ICU"

# %%
# 7. Why does changing medications in patient also affect old_record?
#    Write your answer as a comment below
#

# %% [markdown]
# ---
# ## Section 4 — Methods

# %%
bed_availability = [12, 5, 23, 8, 15, 3, 19, 7]
#                   available beds across 8 wards

# %%
# 1. A new ward opened with 20 beds — add to end

# %%
# 2. Emergency ward with 2 beds needs to go to position 0

# %%
# 3. The ward with 5 beds was closed — remove it

# %%
# 4. Find what position ward with 19 beds is at before sorting

# %%
# 5. Sort in descending order

# %%
# 6. Find what position 19 beds is at after sorting — did it change?

# %%
# 7. Print total beds, highest, lowest, and average beds per ward

# %%
# 8. Remove the last two wards using pop() — print what was removed

# %% [markdown]
# ---
# ## Section 5 — Mixed (Stretch)

# %%
departments  = ["Cardiology", "Neurology", "Orthopedics", "Pediatrics", "Oncology"]
monthly_cost = [320000, 275000, 410000, 190000, 380000]
staff_count  = [45, 30, 38, 25, 42]

# %%
# 1. Print the most expensive and least expensive department
#    by combining departments and monthly_cost using their index

# %%
# 2. Get the top 3 costliest departments after sorting monthly_cost
#    descending — what were their original positions?

# %%
# 3. Add "Dermatology" to departments, 210000 to monthly_cost,
#    and 28 to staff_count — all in one block

# %%
# 4. Remove "Neurology" and its corresponding cost and staff count

# %%
# 5. Calculate cost per staff member for each department
#    using index positions

# %%
# 6. Make a copy of monthly_cost called backup_cost

# %%
# 7. Apply a 10% budget cut to all values in backup_cost
#    using list comprehension

# %%
# 8. Print both — original monthly_cost should be unchanged
